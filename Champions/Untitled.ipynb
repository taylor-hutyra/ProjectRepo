# %%
import json
import pandas as pd

# %%
aatrox_dic = json.load(open('Aatrox.json'))
ahri_dic = json.load(open('Ahri.json'))
akali_dic = json.load(open('Akali.json'))
alistar_dic = json.load(open('Alistar.json'))
amumu_dic = json.load(open('Amumu.json'))
anivia_dic = json.load(open('Anivia.json'))
annie_dic = json.load(open('Annie.json'))
ashe_dic = json.load(open('Ashe.json'))
aurelionsol_dic = json.load(open('AurelionSol.json'))
azir_dic = json.load(open('Azir.json'))
bard_dic = json.load(open('Bard.json'))
blitzcrank_dic = json.load(open('Blitzcrank.json'))
brand_dic = json.load(open('Brand.json'))
braum_dic = json.load(open('Braum.json'))
caitlyn_dic = json.load(open('Caitlyn.json'))
camille_dic = json.load(open('Camille.json'))
cassiopeia_dic = json.load(open('Cassiopeia.json'))
chogath_dic = json.load(open('Chogath.json'))
corki_dic = json.load(open('Corki.json'))
darius_dic = json.load(open('Darius.json'))
diana_dic = json.load(open('Diana.json'))
draven_dic = json.load(open('Draven.json'))
drmundo_dic = json.load(open('DrMundo.json'))
ekko_dic = json.load(open('Ekko.json'))
elise_dic = json.load(open('Elise.json'))
evelynn_dic = json.load(open('Evelynn.json'))
ezreal_dic = json.load(open('Ezreal.json'))
fiddlesticks_dic = json.load(open('FiddleSticks.json'))
fiora_dic = json.load(open('Fiora.json'))
fizz_dic = json.load(open('Fizz.json'))
galio_dic = json.load(open('Galio.json'))
gangplank_dic = json.load(open('Gangplank.json'))
garen_dic = json.load(open('Garen.json'))
gnar_dic = json.load(open('Gnar.json'))
gragas_dic = json.load(open('Gragas.json'))
graves_dic = json.load(open('Graves.json'))
hecarim_dic = json.load(open('Hecarim.json'))
heimerdinger_dic = json.load(open('Heimerdinger.json'))
illaoi_dic = json.load(open('Illaoi.json'))
irelia_dic = json.load(open('Irelia.json'))
ivern_dic = json.load(open('Ivern.json'))
janna_dic = json.load(open('Janna.json'))
jarvaniv_dic = json.load(open('JarvanIV.json'))
jax_dic = json.load(open('Jax.json'))
jayce_dic = json.load(open('Jayce.json'))
jhin_dic = json.load(open('Jhin.json'))
jinx_dic = json.load(open('Jinx.json'))
kalista_dic = json.load(open('Kalista.json'))
karma_dic = json.load(open('Karma.json'))
karthus_dic = json.load(open('Karthus.json'))
kassadin_dic = json.load(open('Kassadin.json'))
katarina_dic = json.load(open('Katarina.json'))
kayle_dic = json.load(open('Kayle.json'))
kennen_dic = json.load(open('Kennen.json'))
khazix_dic = json.load(open('Khazix.json'))
kindred_dic = json.load(open('Kindred.json'))
kled_dic = json.load(open('Kled.json'))
kogmaw_dic = json.load(open('KogMaw.json'))
leblanc_dic = json.load(open('Leblanc.json'))
leesin_dic = json.load(open('LeeSin.json'))
leona_dic = json.load(open('Leona.json'))
lissandra_dic= json.load(open('Lissandra.json'))
lucian_dic = json.load(open('Lucian.json'))
lulu_dic = json.load(open('Lulu.json'))
lux_dic = json.load(open('Lux.json'))
malphite_dic = json.load(open('Malphite.json'))
malzahar_dic = json.load(open('Malzahar.json'))
maokai_dic = json.load(open('Maokai.json'))
masteryi_dic = json.load(open('MasterYi.json'))
missfortune_dic = json.load(open('MissFortune.json'))
monkeyking_dic = json.load(open('MonkeyKing.json'))
mordekaiser_dic = json.load(open('Mordekaiser.json'))
morgana_dic = json.load(open('Morgana.json'))
nami_dic = json.load(open('Nami.json'))
nasus_dic = json.load(open('Nasus.json'))
nautilus_dic = json.load(open('Nautilus.json'))
nidalee_dic = json.load(open('Nidalee.json'))
nocturne_dic = json.load(open('Nocturne.json'))
nunu_dic = json.load(open('Nunu.json'))
olaf_dic = json.load(open('Olaf.json'))
orianna_dic = json.load(open('Orianna.json'))
pantheon_dic = json.load(open('Pantheon.json'))
poppy_dic = json.load(open('Poppy.json'))
quinn_dic = json.load(open('Quinn.json'))
rammus_dic = json.load(open('Rammus.json'))
reksai_dic = json.load(open('RekSai.json'))
renekton_dic = json.load(open('Renekton.json'))
rengar_dic = json.load(open('Rengar.json'))
riven_dic = json.load(open('Riven.json'))
rumble_dic = json.load(open('Rumble.json'))
ryze_dic = json.load(open('Ryze.json'))
sejuani_dic = json.load(open('Sejuani.json'))
shaco_dic = json.load(open('Shaco.json'))
shen_dic = json.load(open('Shen.json'))
shyvana_dic = json.load(open('Shyvana.json'))
singed_dic = json.load(open('Singed.json'))
sion_dic = json.load(open('Sion.json'))
sivir_dic = json.load(open('Sivir.json'))
skarner_dic = json.load(open('Skarner.json'))
sona_dic = json.load(open('Sona.json'))
soraka_dic = json.load(open('Soraka.json'))
swain_dic = json.load(open('Swain.json'))
syndra_dic = json.load(open('Syndra.json'))
tahmkench_dic = json.load(open('TahmKench.json'))
taliyah_dic = json.load(open('Taliyah.json'))
talon_dic = json.load(open('Talon.json'))
taric_dic = json.load(open('Taric.json'))
teemo_dic = json.load(open('Teemo.json'))
thresh_dic = json.load(open('Thresh.json'))
tristana_dic = json.load(open('Tristana.json'))
trundle_dic = json.load(open('Trundle.json'))
tryndamere_dic = json.load(open('Tryndamere.json'))
twistedfate_dic = json.load(open('TwistedFate.json'))
twitch_dic = json.load(open('Twitch.json'))
udyr_dic = json.load(open('Udyr.json'))
urgot_dic = json.load(open('Urgot.json'))
varus_dic = json.load(open('Varus.json'))
vayne_dic = json.load(open('Vayne.json'))
veigar_dic = json.load(open('Veigar.json'))
velkoz_dic = json.load(open('Velkoz.json'))
vi_dic = json.load(open('Vi.json'))
viktor_dic = json.load(open('Viktor.json'))
vladimir_dic = json.load(open('Vladimir.json'))
volibear_dic = json.load(open('Volibear.json'))
warwick_dic = json.load(open('Warwick.json'))
xerath_dic = json.load(open('Xerath.json'))
xinzhao_dic = json.load(open('XinZhao.json'))
yasuo_dic = json.load(open('Yasuo.json'))
yorick_dic = json.load(open('Yorick.json'))
zac_dic = json.load(open('Zac.json'))
zed_dic = json.load(open('Zed.json'))
ziggs_dic = json.load(open('Ziggs.json'))
zilean_dic = json.load(open('Zilean.json'))
zyra_dic = json.load(open('Zyra.json'))

# %%
#aatrox_dic['data']['Aatrox']
#jarvaniv_dic['data']

# %%
all_champs_li = [aatrox_dic['data']['Aatrox'], ahri_dic['data']['Ahri'], akali_dic['data']['Akali'], alistar_dic['data']['Alistar'], amumu_dic['data']['Amumu'], 
                 anivia_dic['data']['Anivia'], annie_dic['data']['Annie'], ashe_dic['data']['Ashe'], aurelionsol_dic['data']['AurelionSol'], azir_dic['data']['Azir'], 
                 bard_dic['data']['Bard'], blitzcrank_dic['data']['Blitzcrank'], brand_dic['data']['Brand'], braum_dic['data']['Braum'], caitlyn_dic['data']['Caitlyn'],
                 camille_dic['data']['Camille'], cassiopeia_dic['data']['Cassiopeia'], chogath_dic['data']['Chogath'], corki_dic['data']['Corki'], darius_dic['data']['Darius'],
                 diana_dic['data']['Diana'], draven_dic['data']['Draven'], drmundo_dic['data']['DrMundo'], ekko_dic['data']['Ekko'], elise_dic['data']['Elise'],
                 evelynn_dic['data']['Evelynn'], ezreal_dic['data']['Ezreal'], fiddlesticks_dic['data']['FiddleSticks'], fiora_dic['data']['Fiora'], fizz_dic['data']['Fizz'],
                 galio_dic['data']['Galio'], gangplank_dic['data']['Gangplank'], garen_dic['data']['Garen'], gnar_dic['data']['Gnar'], gragas_dic['data']['Gragas'],
                 graves_dic['data']['Graves'], hecarim_dic['data']['Hecarim'], heimerdinger_dic['data']['Heimerdinger'], illaoi_dic['data']['Illaoi'], irelia_dic['data']['Irelia'],
                 ivern_dic['data']['Ivern'], janna_dic['data']['Janna'], jarvaniv_dic['data']['JarvanIV'], jax_dic['data']['Jax'], jayce_dic['data']['Jayce'],
                 jhin_dic['data']['Jhin'], jinx_dic['data']['Jinx'], kalista_dic['data']['Kalista'], karma_dic['data']['Karma'], karthus_dic['data']['Karthus'],
                 kassadin_dic['data']['Kassadin'], katarina_dic['data']['Katarina'], kayle_dic['data']['Kayle'], kennen_dic['data']['Kennen'], khazix_dic['data']['Khazix'],
                 kindred_dic['data']['Kindred'], kled_dic['data']['Kled'], kogmaw_dic['data']['KogMaw'], leblanc_dic['data']['Leblanc'], leesin_dic['data']['LeeSin'],
                 leona_dic['data']['Leona'], lissandra_dic['data']['Lissandra'], lucian_dic['data']['Lucian'], lulu_dic['data']['Lulu'], lux_dic['data']['Lux'],
                 malphite_dic['data']['Malphite'], malzahar_dic['data']['Malzahar'], maokai_dic['data']['Maokai'], masteryi_dic['data']['MasterYi'], missfortune_dic['data']['MissFortune'],
                 monkeyking_dic['data']['MonkeyKing'], mordekaiser_dic['data']['Mordekaiser'], morgana_dic['data']['Morgana'], nami_dic['data']['Nami'], nasus_dic['data']['Nasus'],
                 nautilus_dic['data']['Nautilus'], nidalee_dic['data']['Nidalee'], nocturne_dic['data']['Nocturne'], nunu_dic['data']['Nunu'], olaf_dic['data']['Olaf'],
                 orianna_dic['data']['Orianna'], pantheon_dic['data']['Pantheon'], poppy_dic['data']['Poppy'], quinn_dic['data']['Quinn'], rammus_dic['data']['Rammus'],
                 reksai_dic['data']['RekSai'], renekton_dic['data']['Renekton'], rengar_dic['data']['Rengar'], riven_dic['data']['Riven'], rumble_dic['data']['Rumble'],
                 ryze_dic['data']['Ryze'], sejuani_dic['data']['Sejuani'], shaco_dic['data']['Shaco'], shen_dic['data']['Shen'], shyvana_dic['data']['Shyvana'],
                 singed_dic['data']['Singed'], sion_dic['data']['Sion'], sivir_dic['data']['Sivir'], skarner_dic['data']['Skarner'], sona_dic['data']['Sona'], 
                 soraka_dic['data']['Soraka'], swain_dic['data']['Swain'], syndra_dic['data']['Syndra'], tahmkench_dic['data']['TahmKench'], taliyah_dic['data']['Taliyah'],
                 talon_dic['data']['Talon'], taric_dic['data']['Taric'], teemo_dic['data']['Teemo'], thresh_dic['data']['Thresh'], tristana_dic['data']['Tristana'],
                 trundle_dic['data']['Trundle'], tryndamere_dic['data']['Tryndamere'], twistedfate_dic['data']['TwistedFate'], twitch_dic['data']['Twitch'], udyr_dic['data']['Udyr'],
                 urgot_dic['data']['Urgot'], varus_dic['data']['Varus'], vayne_dic['data']['Vayne'], veigar_dic['data']['Veigar'], velkoz_dic['data']['Velkoz'],
                 vi_dic['data']['Vi'], viktor_dic['data']['Viktor'], vladimir_dic['data']['Vladimir'], volibear_dic['data']['Volibear'], warwick_dic['data']['Warwick'],
                 xerath_dic['data']['Xerath'], xinzhao_dic['data']['XinZhao'], yasuo_dic['data']['Yasuo'], yorick_dic['data']['Yorick'], zac_dic['data']['Zac'],
                 zed_dic['data']['Zed'], ziggs_dic['data']['Ziggs'], zilean_dic['data']['Zilean'], zyra_dic['data']['Zyra']]

# %%
#print(type(camille_dic))
#print(all_champs_li)
all_champs_df = pd.DataFrame(all_champs_li)
print(all_champs_df)
# Out:
#                                               allytips  \
# 0    [Avoid engaging in a fight with low health unl...
# 1    [Use Charm to set up your combos, it will make...
# 2    [Akali excels at killing weaker characters. Le...
# 3    [Using Pulverize can allow you to establish be...
# 4    [Amumu is highly dependent on teammates, so tr...
# 5    [Timing Flash Frost with Frostbite can lead to...
# 6    [Storing a stun for use with her ultimate can ...
# 7    [Try to fire Enchanted Crystal Arrow in the sa...
# 8    [You can use Comet of Legend's flight to grow ...
# 9    [Be careful about putting down both of the sol...
# 10   [It's important to collect chimes to improve y...
# 11   [The 1-2-3 combo of Rocket Grab, Power Fist, a...
# 12   [You can deter enemies from standing near thei...
# 13   [Work with your allies to stack Concussive Blo...
# 14   [Make use of her Yordle Snap Traps by placing ...
# 15   [Try waiting until the other team is distracte...
# ...

# %%
all_champs_df.columns.values
# Out:
# array(['allytips', 'blurb', 'enemytips', 'id', 'image', 'info', 'key',
#        'lore', 'name', 'partype', 'passive', 'recommended', 'skins',
#        'spells', 'stats', 'tags', 'title'], dtype=object)
